# %%
import keras
from keras import layers
import numpy as np

# %% [markdown]
# ### GAN generator network

# %%
latent_dim = 32
height = 32
width = 32
channels = 3

generator_input = keras.Input(shape=(latent_dim,))

# Transforms the input into a 16 × 16 128-channel feature map
x = layers.Dense(128 * 16 * 16)(generator_input)
x = layers.LeakyReLU()(x)
x = layers.Reshape((16, 16, 128))(x)

x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# Upsamples to 32 × 32
x = layers.Conv2DTranspose(256, 4, strides=2, padding='same')(x)
x = layers.LeakyReLU()(x)

x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# Produces a 32 × 32 1-channel feature map (shape of a CIFAR10 image)
x = layers.Conv2D(channels, 7, activation='tanh', padding='same')(x)

# Instantiates the generator model, which maps the input of shape (latent_dim,) 
#into an image of shape (32, 32, 3)
generator = keras.models.Model(generator_input, x)
generator.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 32768)             1081344
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 32768)             0
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 16, 16, 256)       819456
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 32, 32, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 32, 32, 3)         37635
# =================================================================
# Total params: 6,264,579
# Trainable params: 6,264,579
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### The GAN discriminator network

# %%
discriminator_input = layers.Input(shape=(height, width, channels))

x = layers.Conv2D(128, 3)(discriminator_input)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Flatten()(x)

# One dropout layer: an important trick
x = layers.Dropout(0.4)(x)

# Classification layer
x = layers.Dense(1, activation='sigmoid')(x)

#Instantiates the discriminator model, which turns a (32, 32, 3) input into a binary 
#classification decision (fake/real)
discriminator = keras.models.Model(discriminator_input, x)
discriminator.summary()

# Uses gradient clipping (by value) in the optimizer and To stabilize training, 
# uses learning-rate decay
discriminator_optimizer = keras.optimizers.RMSprop(lr=0.0008,clipvalue=1.0,decay=1e-8)
discriminator.compile(optimizer=discriminator_optimizer,loss='binary_crossentropy')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 30, 30, 128)       3584
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 14, 14, 128)       262272
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 6, 6, 128)         262272
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 2, 2, 128)         262272
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 790,913
# Trainable params: 790,913
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Adversarial network

# %%
# Sets discriminator weights to non-trainable (this will only apply to the gan model)
discriminator.trainable = False

gan_input = keras.Input(shape=(latent_dim,))
gan_output = discriminator(generator(gan_input))
gan = keras.models.Model(gan_input, gan_output)

gan_optimizer = keras.optimizers.RMSprop(lr=0.0004, clipvalue=1.0, decay=1e-8)
gan.compile(optimizer=gan_optimizer, loss='binary_crossentropy')

# %%
import os
from keras.preprocessing import image

# Loads CIFAR10 data
(x_train, y_train), (_, _) = keras.datasets.cifar10.load_data()

# Selects frog images (class 6)
x_train = x_train[y_train.flatten() == 6]

x_train = x_train.reshape(
    (x_train.shape[0],) +
    (height, width, channels)).astype('float32') / 255.

iterations = 100
batch_size = 20
save_dir = 'Data/GAN'# Specifies where you want to save generated images

start = 0
# Samples random points in the latent space
for step in range(iterations):
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # Decodes them to fake images    
    generated_images = generator.predict(random_latent_vectors)

    # Combines them with real images 
    stop = start + batch_size
    real_images = x_train[start: stop]
    combined_images = np.concatenate([generated_images, real_images])

    labels = np.concatenate([np.ones((batch_size, 1)), np.zeros((batch_size, 1))])
    labels += 0.05 * np.random.random(labels.shape)

    # Trains the discriminator
    d_loss = discriminator.train_on_batch(combined_images, labels)

    # Samples random points in the latent space
    random_latent_vectors = np.random.normal(size=(batch_size,latent_dim))

    # Assembles latent space labels that say “these are all real images” (it’s a lie!)
    misleading_targets = np.zeros((batch_size, 1))

    # Trains the generator (via the gan model, where the discriminator weights are frozen)
    a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)

    start += batch_size
    if start > len(x_train) - batch_size: 
        start = 0

    if step % 100 == 0: 
        gan.save_weights('gan.h5')

    print('discriminator loss:', d_loss)
    print('adversarial loss:', a_loss)

    img = image.array_to_img(generated_images[0] * 255., scale=False)
    img.save(os.path.join(save_dir,
                          'generated_frog' + str(step) + '.png'))

    img = image.array_to_img(real_images[0] * 255., scale=False)
    img.save(os.path.join(save_dir,
                          'real_frog' + str(step) + '.png'))
# Out:
# /anaconda3/lib/python3.6/site-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# discriminator loss: 0.6994072
# adversarial loss: 0.7061756
# discriminator loss: 0.6911387
# adversarial loss: 0.65833914
# discriminator loss: 0.6859323
# adversarial loss: 0.63488835
# discriminator loss: 0.7218493
# adversarial loss: 0.8668865
# discriminator loss: 0.67012423
# adversarial loss: 0.86235064
# discriminator loss: 0.70806575
# adversarial loss: 0.72433794
# discriminator loss: 0.6916459
# adversarial loss: 0.68434083
# discriminator loss: 0.6566482
# adversarial loss: 0.64859474
# discriminator loss: 0.7206206
# adversarial loss: 0.7338933
# discriminator loss: 0.686221
# adversarial loss: 0.7287229
# discriminator loss: 0.6825439
# adversarial loss: 0.7460801
# discriminator loss: 0.666998
# adversarial loss: 0.7139123
# discriminator loss: 0.68412524
# adversarial loss: 0.6670538
# discriminator loss: 0.6965911
# adversarial loss: 0.80930823
# discriminator loss: 0.97988385
# adversarial loss: 1.6382272
# discriminator loss: 0.65670407
# adversarial loss: 2.5128002
# discriminator loss: 1.1696188
# adversarial loss: 1.4640179
# discriminator loss: 0.53628194
# adversarial loss: 1.5551426
# discriminator loss: 0.44978818
# adversarial loss: 1.9205303
# discriminator loss: 0.40422606
# adversarial loss: 2.451833
# discriminator loss: 0.5149137
# adversarial loss: 1.3915595
# discriminator loss: 0.5725759
# adversarial loss: 2.8628027
# discriminator loss: 0.5181135
# adversarial loss: 1.2940699
# discriminator loss: 0.5245584
# adversarial loss: 2.9418702
# discriminator loss: 0.5996604
# adversarial loss: 1.0097778
# discriminator loss: 0.51488733
# adversarial loss: 2.5538573
# discriminator loss: 0.5121304
# adversarial loss: 2.2773862
# discriminator loss: 0.32811457
# adversarial loss: 3.9737046
# discriminator loss: 0.54355824
# adversarial loss: 0.27740243
# discriminator loss: 1.0864604
# adversarial loss: 1.7804339
# discriminator loss: 0.55070734
# adversarial loss: 2.4096043
# discriminator loss: 0.71623075
# adversarial loss: 1.6467896
# discriminator loss: 0.5464532
# adversarial loss: 1.8064034
# discriminator loss: 0.57599276
# adversarial loss: 7.987813
# discriminator loss: 0.6542571
# adversarial loss: 3.7274518
# discriminator loss: 0.44842997
# adversarial loss: 2.7527359
# discriminator loss: 0.45006123
# adversarial loss: 1.0770801
# discriminator loss: 0.5194634
# adversarial loss: 6.6839843
# discriminator loss: 0.79995185
# adversarial loss: 0.77450913
# discriminator loss: 0.5894715
# adversarial loss: 1.3041432
# discriminator loss: 0.5914906
# adversarial loss: 2.1168125
# discriminator loss: 0.35044736
# adversarial loss: 2.7939866
# discriminator loss: 0.44037336
# adversarial loss: 1.7587824
# discriminator loss: 0.5041699
# adversarial loss: 4.943528
# discriminator loss: 0.5961636
# adversarial loss: 3.9612317
# discriminator loss: 0.4907449
# adversarial loss: 3.102352
# discriminator loss: 2.3024187
# adversarial loss: 2.7362168
# discriminator loss: 0.84202176
# adversarial loss: 4.4732614
# discriminator loss: 0.584612
# adversarial loss: 1.2966502
# discriminator loss: 0.75301963
# adversarial loss: 1.2082264
# discriminator loss: 0.6585797
# adversarial loss: 1.0158117
# discriminator loss: 0.71405065
# adversarial loss: 0.94275457
# discriminator loss: 0.7231124
# adversarial loss: 0.913643
# discriminator loss: 0.70152235
# adversarial loss: 1.4722614
# discriminator loss: 0.7324776
# adversarial loss: 1.2142904
# discriminator loss: 0.8241556
# adversarial loss: 0.70499843
# discriminator loss: 0.80913794
# adversarial loss: 0.8061333
